# %% [markdown]
# SCT211-0848/2018
# Jany Muong
# ICS 2207: Scientific Computing
# Computer Science

# %% [markdown]
# # Trade In Low Carbon Technology Dataset
# This file uses data from the [**IMF's Climate Change Dataset**](https://climatedata.imf.org/pages/climatechange-data)
#
# The **Climate Change Data** presents categories that examine carbon dioxide atmospheric concentrations, as well as trends in global warming, such as rising sea levels, rising temperatures and frequency of natural disasters which are key indicators to monitor climate change and its impacts on populations.

# %% [markdown]
# ## Narrative - The `Why` For Choosing This Dataset
#
# The **choice** of the IMF's Climate Change Dataset is strategic. It provides a comprehensive overview of various climate change indicators, offering insights into the environmental challenges we face. By leveraging this dataset, we can analyze the relationship between low carbon technology trade and climate change metrics. This analysis can help policymakers, researchers, and businesses make informed decisions to promote the adoption of low carbon technologies and respond to climate change effectively.

# %% [markdown]
# ### Specifics of the Dataset
# The dataset sourced from the IMF's **Climate Change Dataset** encompasses data on *carbon dioxide atmospheric concentrations*, *global warming trends*, and indicators like *rising sea levels*, *temperatures*, and the *frequency of natural disasters*.
#
# This dataset is invaluable because it offers a comprehensive snapshot of the environmental challenges we're facing due to climate change. By examining carbon dioxide levels, we can gauge the extent of greenhouse gas emission, a primary driver of global warming and we can gain a holistic understanding of the state of our planet's climate and its impacts on both natural and human systems.
#
# This dataset, [`./low_carbon_technology.csv`](./low_carbon_technology.csv) serves as the foundation for our analysis of trade in low carbon technology. We can discern patterns and correlations that shed light on the global transition to a low carbon economy from it, which is relevant to any country and particularly Kenya.
#
# But the **main reason** for why I opted to go with this dataset is: it has enough numerical values which is very convenient for plots and visualisations.

# %% [markdown]
# ## Load Dataset into Notebook

# %%
#!/usr/bin/env python3
'''module: pandas_visualization
this (file) is a solution of the problem set utilizing pandas visualization
          on some open datasets from the internet.
'''

import pandas as pd
import matplotlib.pyplot as plt
from pandas.api.types import is_numeric_dtype

# %%
# load dataset into notebook
df_low_carbon = pd.read_csv('./low_carbon_technology.csv', header=None)
type(df_low_carbon)
# Out:
# pandas.core.frame.DataFrame

# %%
# understand the dataset
# and explore it
df_low_carbon.tail(3)
# Out:
#         0         1   2    3   \
# 2130  2136  Zimbabwe  ZW  ZWE
# 2131  2137  Zimbabwe  ZW  ZWE
# 2132  2138  Zimbabwe  ZW  ZWE
#
#                                                      4           5   \
# 2130  Total trade in low carbon technology products ...     Percent
# 2131    Trade balance in low carbon technology products  US Dollars
# 2132  Trade balance in low carbon technology product...     Percent
#
#                                                      6       7   \
# 2130  Department of Economic and Social Affairs/Unit...   ECBTL
# 2131  Department of Economic and Social Affairs/Unit...  ECBTLB
# 2132  Department of Economic and Social Affairs/Unit...  ECBTLB
#
#                                                      8   \
# 2130            Trade in Low Carbon Technology Products
# 2131  Trade in Low Carbon Technology Products; Trade...
# 2132  Trade in Low Carbon Technology Products; Trade...
#
#                                                      9   ...  \
# ...

# %%
df_low_carbon.head()
# Out:
#          0                             1     2     3   \
# 0  ObjectId                       Country  ISO2  ISO3
# 1         1  Afghanistan, Islamic Rep. of    AF   AFG
# 2         2  Afghanistan, Islamic Rep. of    AF   AFG
# 3         3  Afghanistan, Islamic Rep. of    AF   AFG
# 4         4  Afghanistan, Islamic Rep. of    AF   AFG
#
#                                                   4           5   \
# 0                                          Indicator        Unit
# 1  Comparative advantage in low carbon technology...       Index
# 2          Exports of low carbon technology products  US Dollars
# 3  Exports of low carbon technology products as p...     Percent
# 4  Exports of low carbon technology products as s...     Percent
#
#                                                   6         7   \
# 0                                             Source  CTS_Code
# 1  Department of Economic and Social Affairs/Unit...    ECBTLA
# ...

# %%
# keep original headers;
df_low_carbon = pd.read_csv('./low_carbon_technology.csv')
df_low_carbon
# Out:
#       ObjectId                       Country ISO2 ISO3  \
# 0            1  Afghanistan, Islamic Rep. of   AF  AFG
# 1            2  Afghanistan, Islamic Rep. of   AF  AFG
# 2            3  Afghanistan, Islamic Rep. of   AF  AFG
# 3            4  Afghanistan, Islamic Rep. of   AF  AFG
# 4            5  Afghanistan, Islamic Rep. of   AF  AFG
# ...        ...                           ...  ...  ...
# 2127      2134                      Zimbabwe   ZW  ZWE
# 2128      2135                      Zimbabwe   ZW  ZWE
# 2129      2136                      Zimbabwe   ZW  ZWE
# 2130      2137                      Zimbabwe   ZW  ZWE
# 2131      2138                      Zimbabwe   ZW  ZWE
#
#                                               Indicator        Unit  \
# 0     Comparative advantage in low carbon technology...       Index
# 1             Exports of low carbon technology products  US Dollars
# 2     Exports of low carbon technology products as p...     Percent
# ...

# %%
df_low_carbon.sample(5)
# Out:
#       ObjectId     Country ISO2 ISO3  \
# 538        539  Czech Rep.   CZ  CZE
# 1544      1545    Portugal   PT  PRT
# 1339      1340       Nepal   NP  NPL
# 96          97   Australia   AU  AUS
# 1655      1656  Seychelles   SC  SYC
#
#                                               Indicator     Unit  \
# 538   Trade balance in low carbon technology product...  Percent
# 1544  Trade balance in low carbon technology product...  Percent
# 1339  Trade balance in low carbon technology product...  Percent
# 96    Comparative advantage in low carbon technology...    Index
# 1655  Comparative advantage in low carbon technology...    Index
#
#                                                  Source CTS_Code  \
# 538   Department of Economic and Social Affairs/Unit...   ECBTLB
# 1544  Department of Economic and Social Affairs/Unit...   ECBTLB
# 1339  Department of Economic and Social Affairs/Unit...   ECBTLB
# 96    Department of Economic and Social Affairs/Unit...   ECBTLA
# ...

# %%
# view columns names;
df_low_carbon.columns
# Out:
# Index(['ObjectId', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source',
#        'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', 'Trade_Flow', 'Scale',
#        'F1994', 'F1995', 'F1996', 'F1997', 'F1998', 'F1999', 'F2000', 'F2001',
#        'F2002', 'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009',
#        'F2010', 'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017',
#        'F2018', 'F2019', 'F2020', 'F2021', 'F2022'],
#       dtype='object')

# %% [markdown]
# ## `.describe()` - Describe Tool and Statistics
#
# The `.describe()` method in pandas generates descriptive statistics of a **DataFrame**. It summarizes statistics for numerical columns, such as *count*, *mean*, *standard deviation*, *minimum*, *maximum*, etc.

# %%
df_low_carbon.describe()
# Out:
#           ObjectId         F1994         F1995         F1996         F1997  \
# count  2132.000000  7.200000e+02  8.300000e+02  9.080000e+02  9.480000e+02
# mean   1067.015009  1.385211e+09  1.531140e+09  1.524991e+09  1.541488e+09
# std     616.417108  1.167803e+10  1.380172e+10  1.447518e+10  1.510600e+10
# min       1.000000 -7.093866e+09 -7.571388e+09 -8.445937e+09 -6.727012e+09
# 25%     533.750000  3.382062e-02  4.227062e-02  3.708053e-02  2.405548e-02
# 50%    1066.500000  1.091291e+00  1.084656e+00  1.076960e+00  1.078962e+00
# 75%    1599.250000  5.075036e+07  4.535950e+07  4.330073e+07  3.812333e+07
# max    2138.000000  2.475576e+11  3.145654e+11  3.457233e+11  3.684303e+11
#
#               F1998         F1999         F2000         F2001         F2002  \
# count  1.371000e+03  1.464000e+03  1.669000e+03  1.677000e+03  1.697000e+03
# mean   1.096274e+09  1.093049e+09  1.121185e+09  1.086063e+09  1.098941e+09
# ...

# %%
# include all stats for both numerical and categorical columns.
# the include='all' parameter ensures that statistics for all types of columns are part of the output

df_low_carbon.describe(include='all')
# Out:
#            ObjectId                       Country  ISO2  ISO3  \
# count   2132.000000                          2132  2099  2110
# unique          NaN                           209   203   204
# top             NaN  Afghanistan, Islamic Rep. of    AF   AFG
# freq            NaN                            11    11    11
# mean    1067.015009                           NaN   NaN   NaN
# std      616.417108                           NaN   NaN   NaN
# min        1.000000                           NaN   NaN   NaN
# 25%      533.750000                           NaN   NaN   NaN
# 50%     1066.500000                           NaN   NaN   NaN
# 75%     1599.250000                           NaN   NaN   NaN
# max     2138.000000                           NaN   NaN   NaN
#
#                                         Indicator     Unit  \
# count                                        2132     2132
# unique                                         11        3
# ...

# %%
# get stats similar as pandas .descibe() tool but LESS ans using a for loop;
for col in df_low_carbon.columns:
    if is_numeric_dtype(df_low_carbon[col]):
        print(f'{col}:')
        print(f'\t Mean = {df_low_carbon[col].mean():.2f}')
        print(f'\t Standard Deviation = {df_low_carbon[col].std():.2f}')
        print(f'\t Minimum Value = {df_low_carbon[col].min():.2f}')
        print(f'\t Maximum Value = {df_low_carbon[col].max():.2f}')
# Out:
# ObjectId:
# 	 Mean = 1067.02
# 	 Standard Deviation = 616.42
# 	 Minimum Value = 1.00
# 	 Maximum Value = 2138.00
# F1994:
# 	 Mean = 1385210832.99
# 	 Standard Deviation = 11678031879.38
# 	 Minimum Value = -7093866256.00
# 	 Maximum Value = 247557609365.00
# F1995:
# 	 Mean = 1531139827.99
# 	 Standard Deviation = 13801723833.55
# 	 Minimum Value = -7571388169.00
# 	 Maximum Value = 314565358207.00
# F1996:
# 	 Mean = 1524990507.99
# 	 Standard Deviation = 14475180803.52
# 	 Minimum Value = -8445936804.00
# 	 Maximum Value = 345723273782.00
# F1997:
# 	 Mean = 1541488462.15
# 	 Standard Deviation = 15105999342.89
# 	 Minimum Value = -6727011894.00
# 	 Maximum Value = 368430264149.00
# F1998:
# 	 Mean = 1096274210.56
# 	 Standard Deviation = 12879374755.31
# 	 Minimum Value = -6543204412.00
# 	 Maximum Value = 378135916500.00
# F1999:
# 	 Mean = 1093049009.91
# 	 Standard Deviation = 13264298291.90
# 	 Minimum Value = -7157957802.00
# 	 Maximum Value = 401905736600.00
# F2000:
# ...

# %%
''' 
isolate the ISO3 column and get counts for each country
see occurrence of each ISO3 code to see country's participation in the trade;
'''
df_low_carbon['ISO3'].value_counts()
# Out:
# ISO3
# AFG    11
# RUS    11
# MMR    11
# NAM    11
# NPL    11
#        ..
# FSM     3
# HTI     2
# TCD     2
# WLF     1
# COK     1
# Name: count, Length: 204, dtype: int64

# %%
# filter relevant columns for covariance - numerical columns
df_stats = ['F1994', 'F1995', 'F1996', 'F1997', 'F1998', 'F1999', 'F2000', 'F2001',
       'F2002', 'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009',
       'F2010', 'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017',
       'F2018', 'F2019', 'F2020', 'F2021', 'F2022']
print('Covarience')
df_cov = df_low_carbon[df_stats]
df_cov.cov()
# Out:
# Covarience
#               F1994         F1995         F1996         F1997         F1998  \
# F1994  1.363764e+20  1.813323e+20  2.102822e+20  2.335117e+20  2.264277e+20
# F1995  1.813323e+20  1.904876e+20  2.263315e+20  2.551057e+20  2.558575e+20
# F1996  2.102822e+20  2.263315e+20  2.095309e+20  2.393237e+20  2.421466e+20
# F1997  2.335117e+20  2.551057e+20  2.393237e+20  2.281912e+20  2.439816e+20
# F1998  2.264277e+20  2.558575e+20  2.421466e+20  2.439816e+20  1.658783e+20
# F1999  2.292053e+20  2.637368e+20  2.523261e+20  2.584349e+20  1.848712e+20
# F2000  2.726401e+20  2.998536e+20  2.911496e+20  3.014126e+20  2.142333e+20
# F2001  2.700789e+20  2.963223e+20  2.841154e+20  2.911355e+20  2.092569e+20
# F2002  2.732363e+20  2.979008e+20  2.919700e+20  2.989973e+20  2.134027e+20
# F2003  3.218282e+20  3.586379e+20  3.456111e+20  3.566003e+20  2.544352e+20
# F2004  4.126522e+20  4.488382e+20  4.419049e+20  4.552474e+20  3.252944e+20
# ...

# %%
# filter relevant columns for correlation - numerical columns
df_stats = ['F1994', 'F1995', 'F1996', 'F1997', 'F1998', 'F1999', 'F2000', 'F2001',
       'F2002', 'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009',
       'F2010', 'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017',
       'F2018', 'F2019', 'F2020', 'F2021', 'F2022']
print('Correlation')
df_corr = df_low_carbon[df_stats]
df_corr.corr()
# Out:
# Correlation
#           F1994     F1995     F1996     F1997     F1998     F1999     F2000  \
# F1994  1.000000  0.999857  0.999614  0.998848  0.998480  0.998642  0.998399
# F1995  0.999857  1.000000  0.999690  0.998712  0.998291  0.998486  0.998180
# F1996  0.999614  0.999690  1.000000  0.999477  0.999150  0.999169  0.998685
# F1997  0.998848  0.998712  0.999477  1.000000  0.999555  0.999527  0.999222
# F1998  0.998480  0.998291  0.999150  0.999555  1.000000  0.999811  0.999015
# F1999  0.998642  0.998486  0.999169  0.999527  0.999811  1.000000  0.999578
# F2000  0.998399  0.998180  0.998685  0.999222  0.999015  0.999578  1.000000
# F2001  0.997930  0.997643  0.998538  0.999078  0.999502  0.999710  0.999428
# F2002  0.997634  0.997450  0.998343  0.998413  0.999011  0.999153  0.998689
# F2003  0.996084  0.996000  0.996869  0.996505  0.997126  0.997230  0.996758
# F2004  0.994271  0.994254  0.994940  0.994212  0.994813  0.995009  0.994687
# ...

# %% [markdown]
# ### Filter the DataFrame - Columns For Low Carbon Adoption
#
# These columns provide data on the trade, investment, emissions, and environmental aspects related to low carbon technologies and practices. Analyzing these columns can help evaluate the level of adoption and the effectiveness of low carbon initiatives in each country or region.

# %%
# filter the DataFrame to include only relevant columns related to low carbon adoption;
relevant_columns = ['Country', 'ISO3', 'Indicator', 'Unit', 'CTS_Full_Descriptor',
                    'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022']
df_low_carbon_rel = df_low_carbon[relevant_columns]

# %% [markdown]
# #### assess low carbon adoption based on specific indicators

# %%
# assess low carbon adoption based on specific indicators
# example 1: imports of low carbon technology products as percent of total trade
imports_indicator = df_low_carbon_rel[df_low_carbon_rel['Indicator'].str.contains('Imports of low carbon technology products')]
imports_values = imports_indicator[['Country', 'ISO3', 'Indicator', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022']]
print('Imports of low carbon technology products:')
print(imports_values)
# Out:
# Imports of low carbon technology products:
#                            Country ISO3  \
# 4     Afghanistan, Islamic Rep. of  AFG
# 5     Afghanistan, Islamic Rep. of  AFG
# 6     Afghanistan, Islamic Rep. of  AFG
# 15                         Albania  ALB
# 16                         Albania  ALB
# ...                            ...  ...
# 2115                        Zambia  ZMB
# 2116                        Zambia  ZMB
# 2125                      Zimbabwe  ZWE
# 2126                      Zimbabwe  ZWE
# 2127                      Zimbabwe  ZWE
#
#                                               Indicator         F2013  \
# 4             Imports of low carbon technology products           NaN
# 5     Imports of low carbon technology products as p...           NaN
# 6     Imports of low carbon technology products as s...           NaN
# 15            Imports of low carbon technology products  1.144081e+08
# 16    Imports of low carbon technology products as p...  8.949622e-01
# ...

# %%
# assess low carbon adoption based on specific indicators
# example 2: trade balance in low carbon technology products in US dollars
trade_balance_indicator = df_low_carbon_rel[df_low_carbon_rel['Indicator'].str.contains('Trade balance in low carbon technology products')]
trade_balance_values = trade_balance_indicator[['Country', 'ISO3', 'Indicator',
                                                'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022']]
print('Trade balance in low carbon technology products:')
print(trade_balance_values)
# Out:
# Trade balance in low carbon technology products:
#                            Country ISO3  \
# 9     Afghanistan, Islamic Rep. of  AFG
# 10    Afghanistan, Islamic Rep. of  AFG
# 20                         Albania  ALB
# 21                         Albania  ALB
# 31                         Algeria  DZA
# ...                            ...  ...
# 2109                Yemen, Rep. of  YEM
# 2119                        Zambia  ZMB
# 2120                        Zambia  ZMB
# 2130                      Zimbabwe  ZWE
# 2131                      Zimbabwe  ZWE
#
#                                               Indicator         F2013  \
# 9       Trade balance in low carbon technology products           NaN
# 10    Trade balance in low carbon technology product...           NaN
# 20      Trade balance in low carbon technology products -9.597174e+07
# 21    Trade balance in low carbon technology product... -7.507429e-01
# 31      Trade balance in low carbon technology products -3.034324e+09
# ...

# %% [markdown]
# ## Pandas Visualizations
# We can create high-quality figures and graphics for the Low Carbon Dataset and also	plot and make sexy visualizations from the results.

# %%
# %matplotlib inline

# define helper column headers(filter)
df_stats_tail5 = ['F2018', 'F2019', 'F2020', 'F2021', 'F2022']
df_stats_head5 = ['F1994', 'F1995', 'F1996', 'F1997', 'F1998']
df_stats_mid = ['F2005', 'F2006', 'F2007', 'F2008', 'F2009', 'F2010', 'F2011', 'F2012', 'F2013', 'F2014']

# %%
# trend for last 5 years from dataset

df_low_carbon[df_stats_tail5].plot()
plt.title('Low Carbon Trade Trend')
plt.show()

# %%
'''get low carbon tech adoption for the last 5 years
    in a box plot
'''
df_box = df_low_carbon[df_stats_tail5]
df_box.plot(kind='box')
plt.title('Box Plot: Low Carbon Tech Distribution')
plt.show()

# %%
'''scatter plots visualizations
'''
df_low_carbon.plot(kind='scatter', x='CTS_Code', y='F2019')
plt.title('Scatter Plot: Low Carbon Tech Distribution')
plt.show()

# %%
# histogram for first 5 years
df_hist = df_low_carbon[df_stats_head5]
df_hist.hist(bins=10)
plt.show()

# %%
# histogram for 2022
df_low_carbon['F2022'].hist(bins=10)
plt.title('Histogram for the Year 2022')
plt.show()

# %%
import seaborn as sns

# print('Correlation Heat Map')
df_corr = df_low_carbon[['F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(df_corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Kernel Density Estimation (KDE) Plot for 2005 through 2014
df_kde = df_low_carbon[df_stats_mid]
df_kde.plot(kind='kde')
plt.title('KDE Plot for 2005 through 2014')
plt.show()

# %%
# scatter plot for F2013 vs F2014
plt.scatter(df_low_carbon['F2013'], df_low_carbon['F2014'])
plt.xlabel('F2013')
plt.ylabel('F2014')
plt.title('Scatter plot: F2013 vs F2014')
plt.show()

# %%
# box plot for numerical column F2013
plt.boxplot(df_low_carbon['F2013'].dropna())
plt.xlabel('F2013')
plt.title('Box plot of F2013')
plt.show()

# %%
#ne plot for trend of F2013 to F2022 for a specific country
plt.plot(df_low_carbon.loc[df_low_carbon['Country'] == 'Kenya', 'F2013':'F2022'].T)
plt.xlabel('Year')
plt.ylabel('Values')
plt.title('Trend of F2013 Through F2022 for Kenya')
plt.legend(df_low_carbon.columns[9:])
plt.show()

# %%
'''Histogram for numerical column F2013'''

# first drop values that are NaN
plt.hist(df_low_carbon['F2013'].dropna(), bins=20)
plt.xlabel('F2013 Values')
plt.ylabel('Frequency')
plt.title('Histogram of F2013 Values')
plt.show()

# %%
'''Histogram for categorical column Country'''

plt.figure(figsize=(10, 6))

df_low_carbon['Country'].value_counts().plot(kind='bar')
plt.xlabel('Country')
plt.ylabel('Frequency')
plt.title('Frequency of Countries')
plt.xticks(rotation=45)
plt.show()

# %%
# stacked area plot for cumulative exports over years
plt.stackplot(df_low_carbon['Country'], df_low_carbon['F2020'], df_low_carbon['F2021'], df_low_carbon['F2022'],
              labels=['F2020', 'F2021', 'F2022'])
plt.xlabel('Country')
plt.ylabel('Cumulative Exports')
plt.title('Cumulative Exports Over Years')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %%
# Pie chart for distribution of ISO3 codes
plt.figure(figsize=(8, 8))
df_low_carbon['ISO3'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of ISO3 Codes')
plt.ylabel('')
plt.show()

# %%
# Violin plot for F2013
plt.violinplot(df_low_carbon['F2013'].dropna())
plt.xlabel('F2013')
plt.title('Violin Plot of F2013')
plt.show()

# %% [markdown]
# ## End File
