# %% [markdown]
# # Deep Learning in Pytorch

# %% [markdown]
# > ### neural netwroks:
# > deep learning models/architectures in pytorch

# %%
import torch
print(f'Pytorch Version: {torch.__version__}')
# Out:
# Pytorch Version: 2.9.0

# %%
from IPython.display import Image
image_path = './single-neuron.png'
Image(filename=image_path)

# %% [markdown]
# > ### what happens:
# > the example image above is the working of a neuron for a generic linear model; and how this works is - the model will try to figure out the linear r'ship of the features and targets; essentially getting a line of best fit that ideally captures the r'ship close enough.

# %% [markdown]
# ### neural nets
#
# > #### building blocks
# > it is made up of single neurons that build up to form the network;
# the working of the network under the hood is the same as the working of single neuron but bundled togehter weith others. pytorch handles this complexity regardless
# >
# > there is input layers + hidden layers + output layers

# %% [markdown]
# ### the ml pipeline:
# a typical machine learning pipeline looks this way:

# %% [markdown]
# <img src="ml-pipeline.png" width="960" height="64">

# %% [markdown]
# ## model:

# %%
## look at the neural network model example in the 00-neural-net-model.ipynb notebook
