# %% [markdown]
# ## ReLU - an activation function of neural networks:

# %% [markdown]
# this is a way of tranforming non-linearly a linear model. it allows a model to learn richer patterns.
#
# a relu looks like this:
#
# ```python
# if input > 0:
#     return input
# else
#     return 0
#
# # nn,ReLU in pytorch(see below)
# ```

# %% [markdown]
# ---
#
# ```python
# model = nn.Sequential(
#     nn.linear(1,3) # 1 input neuron for inout, 3 output neruon to be passed to ReLU
#     nn.ReLU()
#     nn.linear(3,1) # takes the relu'd outpu and gives one ouput using 1 ouput neuron
# )
# ```

# %% [markdown]
# ### ReLU for modeling curves
# eg when a bike delivery system encounters traffic, it would be wrong to have a model for linear time(only).
# in essence relu would be applied in a situation where a model is used to model non-linear time:
# $time = w * distance + b$
# $relu(time)$

# %% [markdown]
# ## other activation functions
# tanh, sigmoid etc
